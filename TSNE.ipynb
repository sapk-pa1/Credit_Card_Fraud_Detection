# %%
from sklearn.manifold import TSNE
import pandas as pd

# %%
from sklearn.manifold import TSNE
import pandas as pd
tsne = TSNE()
def dim_reduc(x) :
    x_embedded = tsne.fit_transform(x)
    x_embedded_df=pd.DataFrame(x_embedded)
    x_embedded_df.to_csv('reduced_data.csv',index=None)

# %%
dataset = pd.read_csv("./dataset/creditcard.csv")

# %%
sample_data = dataset.sample(frac = 0.5, random_state = 1)

# %%
sample_data
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 169876  119907.0 -0.611712 -0.769705 -0.149759 -0.224877  2.028577 -2.019887
# 127467   78340.0 -0.814682  1.319219  1.329415  0.027273 -0.284871 -0.653985
# 137900   82382.0 -0.318193  1.118618  0.969864 -0.127052  0.569563 -0.532484
# 21513    31717.0 -1.328271  1.018378  1.775426 -1.574193 -0.117696 -0.457733
# 134700   80923.0  1.276712  0.617120 -0.578014  0.879173  0.061706 -1.472002
# ...          ...       ...       ...       ...       ...       ...       ...
# 22954    32519.0  1.157029  0.274859  0.387850  0.573217 -0.209966 -0.390377
# 54125    46295.0  1.567927 -1.067331 -0.391116 -1.688535 -0.626932  0.126477
# 122292   76504.0 -5.510713  4.018880 -4.926666 -2.950137 -0.903138  2.114806
# 216759  140619.0 -1.640903  1.004378  1.499580  1.014818 -0.448262  0.044925
# 225362  144216.0  1.921208 -2.205423 -0.015198 -1.625202 -2.130128  0.299614
#
# ...
